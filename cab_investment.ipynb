# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import plotly.express as px

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
cab_data = pd.read_csv('/Users/krutarthmac/Downloads/DataSets-main/cab_cleaned.csv')

# %%
cab_data
# Out:
#         Transaction ID Date of Travel  Company            City  KM Travelled  \
# 0             10002654       1/9/2016        1   WASHINGTON DC          3.54
# 1             10002655      1/14/2016        1   WASHINGTON DC         28.08
# 2             10002656       1/9/2016        1   WASHINGTON DC         35.96
# 3             10002657      1/13/2016        1   WASHINGTON DC          8.96
# 4             10002658      1/13/2016        1   WASHINGTON DC         18.54
# ...                ...            ...      ...             ...           ...
# 359387        10219947       9/8/2017        1  LOS ANGELES CA         12.61
# 359388        10220032       9/8/2017        1  LOS ANGELES CA         13.26
# 359389        10219890       9/8/2017        1  LOS ANGELES CA         14.43
# 359390        10220125       9/8/2017        1  LOS ANGELES CA         15.68
# 359391        10220021       9/8/2017        1  LOS ANGELES CA         17.12
#
#         Price Charged  Cost of Trip
# ...

# %%
cab_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359392 non-null  int64
#  1   Date of Travel  359392 non-null  object
#  2   Company         359392 non-null  int64
#  3   City            359392 non-null  object
#  4   KM Travelled    359392 non-null  float64
#  5   Price Charged   359392 non-null  float64
#  6   Cost of Trip    359392 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 19.2+ MB

# %%
cab_data.describe()
# Out:
#        Transaction ID        Company   KM Travelled  Price Charged  \
# count    3.593920e+05  359392.000000  359392.000000  359392.000000
# mean     1.022076e+07       1.235706      22.567254     423.443311
# std      1.268058e+05       0.424440      12.233526     274.378911
# min      1.000001e+07       1.000000       1.900000      15.600000
# 25%      1.011081e+07       1.000000      12.000000     206.437500
# 50%      1.022104e+07       1.000000      22.440000     386.360000
# 75%      1.033094e+07       1.000000      32.960000     583.660000
# max      1.044011e+07       2.000000      48.000000    2048.030000
#
#         Cost of Trip
# count  359392.000000
# mean      286.190113
# std       157.993661
# min        19.000000
# 25%       151.200000
# 50%       282.480000
# 75%       413.683200
# max       691.200000

# %%
cab_data.isnull().sum()
# Out:
# Transaction ID    0
# Date of Travel    0
# Company           0
# City              0
# KM Travelled      0
# Price Charged     0
# Cost of Trip      0
# dtype: int64

# %%
cab_data = cab_data.drop_duplicates()

# %%
std_cab = cab_data.std()
print(std_cab)
# Out:
# Transaction ID    126805.803715
# Company                0.424440
# KM Travelled          12.233526
# Price Charged        274.378911
# Cost of Trip         157.993661
# dtype: float64

# %%
skew_cab = cab_data.skew()
print(skew_cab)
# Out:
# Transaction ID    0.000072
# Company           1.245382
# KM Travelled      0.055779
# Price Charged     0.873761
# Cost of Trip      0.137958
# dtype: float64

# %%
kurtosis_cab = cab_data.kurt()
print(kurtosis_cab)
# Out:
# Transaction ID   -1.198925
# Company          -0.449026
# KM Travelled     -1.126875
# Price Charged     0.747635
# Cost of Trip     -1.012233
# dtype: float64

# %%
cab_data.mode(axis=0, numeric_only=False, dropna=True)
# Out:
#         Transaction ID Date of Travel  Company         City  KM Travelled  \
# 0             10000011       1/5/2018      1.0  NEW YORK NY          33.6
# 1             10000012            NaN      NaN          NaN           NaN
# 2             10000013            NaN      NaN          NaN           NaN
# 3             10000014            NaN      NaN          NaN           NaN
# 4             10000015            NaN      NaN          NaN           NaN
# ...                ...            ...      ...          ...           ...
# 359387        10440101            NaN      NaN          NaN           NaN
# 359388        10440104            NaN      NaN          NaN           NaN
# 359389        10440105            NaN      NaN          NaN           NaN
# 359390        10440106            NaN      NaN          NaN           NaN
# 359391        10440107            NaN      NaN          NaN           NaN
#
#         Price Charged  Cost of Trip
# 0              191.27        362.88
# ...

# %% [markdown]
# #### Cordinality

# %%
cab_data.nunique()
# Out:
# Transaction ID    359392
# Date of Travel      1095
# Company                2
# City                  19
# KM Travelled         874
# Price Charged      99176
# Cost of Trip       16291
# dtype: int64

# %% [markdown]
# #### Histograms

# %%
plt.figure(figsize=(6,4))
sns.histplot(data = cab_data['KM Travelled'], bins = 25)
# Out:
# <AxesSubplot: xlabel='KM Travelled', ylabel='Count'>

# %%
plt.figure(figsize=(6,4))
sns.histplot(data = cab_data['Price Charged'], bins = 25)
# Out:
# <AxesSubplot: xlabel='Price Charged', ylabel='Count'>

# %%
plt.figure(figsize=(6,4))
sns.histplot(data = cab_data['Cost of Trip'], bins = 25)
# Out:
# <AxesSubplot: xlabel='Cost of Trip', ylabel='Count'>

# %%
sns.displot(data = cab_data, x="KM Travelled", hue="City")

# %%
sns.displot(data = cab_data, x="Price Charged", hue="City")

# %%
sns.displot(data = cab_data, x="Cost of Trip", hue="City")

# %%
plt.figure(figsize=(6,4))
sns.displot(data = cab_data, x="KM Travelled", hue="Company", multiple="dodge", bins = 10)

# %%
plt.figure(figsize=(6,4))
sns.displot(data = cab_data, x="Price Charged", hue="Company", multiple="dodge", bins = 10)

# %%
plt.figure(figsize=(6,4))
sns.displot(data = cab_data, x="Cost of Trip", hue="Company", multiple="dodge", bins = 10)

# %%
sns.displot(data = cab_data, x="Cost of Trip", col="Company", bins = 25)

# %%
sns.displot(data = cab_data, x="Price Charged", col="Company", bins = 25)

# %%
sns.displot(data = cab_data, x="KM Travelled", col="Company", bins = 25)

# %%
sns.displot(data = cab_data, x="KM Travelled", hue="Company", kind="kde", fill=True)

# %%
sns.displot(data = cab_data, x="Price Charged", hue="Company", kind="kde", fill=True)

# %%
sns.displot(data = cab_data, x="Cost of Trip", hue="Company", kind="kde", fill=True)

# %% [markdown]
# #### Correlation Analysis

# %%
cab_data[['KM Travelled', 'Price Charged', 'Cost of Trip']].corr(method ='pearson')
# Out:
#                KM Travelled  Price Charged  Cost of Trip
# KM Travelled       1.000000       0.835753      0.981848
# Price Charged      0.835753       1.000000      0.859812
# Cost of Trip       0.981848       0.859812      1.000000

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(data=cab_data, x="KM Travelled", y="Price Charged", hue="Company")
# Out:
# <AxesSubplot: xlabel='KM Travelled', ylabel='Price Charged'>

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(data=cab_data, x="KM Travelled", y="Cost of Trip", hue="Company")
# Out:
# <AxesSubplot: xlabel='KM Travelled', ylabel='Cost of Trip'>

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(data=cab_data, x="Price Charged", y="Cost of Trip", hue="Company")
# Out:
# <AxesSubplot: xlabel='Price Charged', ylabel='Cost of Trip'>

# %% [markdown]
# ### Customer ID EDA

# %%
customer_id = pd.read_csv('/Users/krutarthmac/Downloads/DataSets-main/Customer_ID.csv')

# %%
customer_id
# Out:
#        Customer ID  Gender  Age  Income (USD/Month)
# 0            29290    Male   28               10813
# 1            27703    Male   27                9237
# 2            28712    Male   53               11242
# 3            28020    Male   23               23327
# 4            27182    Male   33                8536
# ...            ...     ...  ...                 ...
# 49166        12490    Male   33               18713
# 49167        14971    Male   30               15346
# 49168        41414    Male   38                3960
# 49169        41677    Male   23               19454
# 49170        39761  Female   32               10128
#
# [49171 rows x 4 columns]

# %%
customer_id.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49171 entries, 0 to 49170
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         49171 non-null  int64
#  1   Gender              49171 non-null  object
#  2   Age                 49171 non-null  int64
#  3   Income (USD/Month)  49171 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
customer_id.describe()
# Out:
#         Customer ID           Age  Income (USD/Month)
# count  49171.000000  49171.000000        49171.000000
# mean   28398.252283     35.363121        15015.631856
# std    17714.137333     12.599066         8002.208253
# min        1.000000     18.000000         2000.000000
# 25%    12654.500000     25.000000         8289.500000
# 50%    27631.000000     33.000000        14656.000000
# 75%    43284.500000     42.000000        21035.000000
# max    60000.000000     65.000000        35000.000000

# %%
customer_id.isnull().sum()
# Out:
# Customer ID           0
# Gender                0
# Age                   0
# Income (USD/Month)    0
# dtype: int64

# %%
customer_id = customer_id.drop_duplicates()

# %%
customer_id.std()
# Out:
# Customer ID           17714.137333
# Age                      12.599066
# Income (USD/Month)     8002.208253
# dtype: float64

# %%
customer_id.skew()
# Out:
# Customer ID           0.141494
# Age                   0.685934
# Income (USD/Month)    0.313148
# dtype: float64

# %%
customer_id.kurt()
# Out:
# Customer ID          -1.192502
# Age                  -0.451938
# Income (USD/Month)   -0.672325
# dtype: float64

# %%
customer_id.mode(axis=0, numeric_only=False, dropna=True)
# Out:
#        Customer ID Gender   Age  Income (USD/Month)
# 0                1   Male  20.0              8497.0
# 1                2    NaN   NaN                 NaN
# 2                3    NaN   NaN                 NaN
# 3                4    NaN   NaN                 NaN
# 4                5    NaN   NaN                 NaN
# ...            ...    ...   ...                 ...
# 49166        59996    NaN   NaN                 NaN
# 49167        59997    NaN   NaN                 NaN
# 49168        59998    NaN   NaN                 NaN
# 49169        59999    NaN   NaN                 NaN
# 49170        60000    NaN   NaN                 NaN
#
# [49171 rows x 4 columns]

# %%
customer_id.nunique()
# Out:
# Customer ID           49171
# Gender                    2
# Age                      48
# Income (USD/Month)    23341
# dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.histplot(data = customer_id['Income (USD/Month)'], bins = 25)
# Out:
# <AxesSubplot: xlabel='Income (USD/Month)', ylabel='Count'>

# %%
sns.displot(data = customer_id, x="Income (USD/Month)", hue="Gender")

# %%
sns.displot(data = customer_id, x="Age", hue="Gender")

# %%
sns.displot(data = customer_id, x="Income (USD/Month)", hue="Gender", multiple="dodge", bins = 10)

# %%
sns.displot(data = customer_id, x="Income (USD/Month)", col="Gender", bins = 25)

# %%
sns.displot(data = customer_id, x="Income (USD/Month)", hue="Gender", kind="kde", fill=True)

# %%
plt.figure(figsize=(4,3))
sns.boxplot(data = customer_id, x="Income (USD/Month)", y ="Gender")
# Out:
# <AxesSubplot: xlabel='Income (USD/Month)', ylabel='Gender'>

# %%
customer_id[['Age','Income (USD/Month)']].corr(method ='pearson')
# Out:
#                          Age  Income (USD/Month)
# Age                 1.000000            0.000156
# Income (USD/Month)  0.000156            1.000000

# %% [markdown]
# ### Transaction ID EDA

# %%
transaction_id = pd.read_csv('/Users/krutarthmac/Downloads/DataSets-main/Transaction_ID.csv')

# %%
transaction_id
# Out:
#         Transaction ID  Customer ID Payment_Mode
# 0             10000011        29290         Card
# 1             10000012        27703         Card
# 2             10000013        28712         Cash
# 3             10000014        28020         Cash
# 4             10000015        27182         Card
# ...                ...          ...          ...
# 440093        10440104        53286         Cash
# 440094        10440105        52265         Cash
# 440095        10440106        52175         Card
# 440096        10440107        52917         Card
# 440097        10440108        51587         Card
#
# [440098 rows x 3 columns]

# %%
transaction_id_merged = pd.merge(customer_id, transaction_id, on="Customer ID", how="left")

# %%
transaction_id_merged
# Out:
#         Customer ID  Gender  Age  Income (USD/Month)  Transaction ID  \
# 0             29290    Male   28               10813        10000011
# 1             29290    Male   28               10813        10351127
# 2             29290    Male   28               10813        10412921
# 3             27703    Male   27                9237        10000012
# 4             27703    Male   27                9237        10320494
# ...             ...     ...  ...                 ...             ...
# 440093        12490    Male   33               18713        10439799
# 440094        14971    Male   30               15346        10439820
# 440095        41414    Male   38                3960        10439838
# 440096        41677    Male   23               19454        10439840
# 440097        39761  Female   32               10128        10439846
#
#        Payment_Mode
# 0              Card
# 1              Cash
# 2              Card
# 3              Card
# 4              Card
# ...

# %%
all_merged = pd.merge(cab_data, transaction_id_merged, on="Transaction ID", how="left")

# %%
all_merged
# Out:
#         Transaction ID Date of Travel  Company            City  KM Travelled  \
# 0             10002654       1/9/2016        1   WASHINGTON DC          3.54
# 1             10002655      1/14/2016        1   WASHINGTON DC         28.08
# 2             10002656       1/9/2016        1   WASHINGTON DC         35.96
# 3             10002657      1/13/2016        1   WASHINGTON DC          8.96
# 4             10002658      1/13/2016        1   WASHINGTON DC         18.54
# ...                ...            ...      ...             ...           ...
# 359387        10219947       9/8/2017        1  LOS ANGELES CA         12.61
# 359388        10220032       9/8/2017        1  LOS ANGELES CA         13.26
# 359389        10219890       9/8/2017        1  LOS ANGELES CA         14.43
# 359390        10220125       9/8/2017        1  LOS ANGELES CA         15.68
# 359391        10220021       9/8/2017        1  LOS ANGELES CA         17.12
#
# ...

# %%
all_merged['Date of Travel'] = pd.to_datetime(all_merged['Date of Travel'])

# %%
all_merged['Day']=all_merged['Date of Travel'].dt.day_name()

# %%
all_merged = all_merged.sort_values(by = 'Date of Travel')

# %%
all_merged.City.value_counts()
# Out:
# NEW YORK NY       99885
# CHICAGO IL        56625
# LOS ANGELES CA    48033
# WASHINGTON DC     43737
# BOSTON MA         29692
# SAN DIEGO CA      20488
# SILICON VALLEY     8519
# SEATTLE WA         7997
# ATLANTA GA         7557
# DALLAS TX          7017
# MIAMI FL           6454
# AUSTIN TX          4896
# ORANGE COUNTY      3982
# DENVER CO          3825
# NASHVILLE TN       3010
# SACRAMENTO CA      2367
# PHOENIX AZ         2064
# TUCSON AZ          1931
# PITTSBURGH PA      1313
# Name: City, dtype: int64

# %% [markdown]
# We can see that NYC had most of the cab users and Pittsburgh had least of the cab users.

# %%
sns.barplot(x='Day', y = 'KM Travelled', data=all_merged)
# Out:
# <AxesSubplot: xlabel='Day', ylabel='KM Travelled'>

# %%
sns.barplot(x='Day', y = 'Price Charged', data=all_merged)
# Out:
# <AxesSubplot: xlabel='Day', ylabel='Price Charged'>

# %%
sns.barplot(x='Day', y = 'Cost of Trip', data=all_merged)
# Out:
# <AxesSubplot: xlabel='Day', ylabel='Cost of Trip'>

# %% [markdown]
# After analyzing the above both plots we can say that price was charged more than the cost of trip for making profits.

# %%
ax = all_merged.plot(x='Date of Travel', y='Price Charged', figsize=(12,6))
plt.ylim([1000, 2500])
# Out:
# (1000.0, 2500.0)

# %%
ax = all_merged.plot(x='Date of Travel', y='Cost of Trip', figsize=(12,6))
plt.ylim([600,700])
# Out:
# (600.0, 700.0)

# %%
all_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359392 entries, 11294 to 205760
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Transaction ID      359392 non-null  int64
#  1   Date of Travel      359392 non-null  datetime64[ns]
#  2   Company             359392 non-null  int64
#  3   City                359392 non-null  object
#  4   KM Travelled        359392 non-null  float64
#  5   Price Charged       359392 non-null  float64
#  6   Cost of Trip        359392 non-null  float64
#  7   Customer ID         359392 non-null  int64
#  8   Gender              359392 non-null  object
#  9   Age                 359392 non-null  int64
#  10  Income (USD/Month)  359392 non-null  int64
#  11  Payment_Mode        359392 non-null  object
#  12  Day                 359392 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(5), object(4)
# memory usage: 38.4+ MB

# %%
all_merged.describe()
# Out:
#        Transaction ID        Company   KM Travelled  Price Charged  \
# count    3.593920e+05  359392.000000  359392.000000  359392.000000
# mean     1.022076e+07       1.235706      22.567254     423.443311
# std      1.268058e+05       0.424440      12.233526     274.378911
# min      1.000001e+07       1.000000       1.900000      15.600000
# 25%      1.011081e+07       1.000000      12.000000     206.437500
# 50%      1.022104e+07       1.000000      22.440000     386.360000
# 75%      1.033094e+07       1.000000      32.960000     583.660000
# max      1.044011e+07       2.000000      48.000000    2048.030000
#
#         Cost of Trip    Customer ID            Age  Income (USD/Month)
# count  359392.000000  359392.000000  359392.000000       359392.000000
# mean      286.190113   19191.652115      35.336705        15048.822937
# std       157.993661   21012.412463      12.594234         7969.409482
# min        19.000000       1.000000      18.000000         2000.000000
# ...

# %%
all_merged.isnull().sum()
# Out:
# Transaction ID        0
# Date of Travel        0
# Company               0
# City                  0
# KM Travelled          0
# Price Charged         0
# Cost of Trip          0
# Customer ID           0
# Gender                0
# Age                   0
# Income (USD/Month)    0
# Payment_Mode          0
# Day                   0
# dtype: int64

# %%
all_merged = all_merged.drop_duplicates()

# %%
all_merged.std()
# Out:
# Transaction ID                      126805.803715
# Date of Travel        307 days 11:12:45.823193004
# Company                                   0.42444
# KM Travelled                            12.233526
# Price Charged                          274.378911
# Cost of Trip                           157.993661
# Customer ID                          21012.412463
# Age                                     12.594234
# Income (USD/Month)                    7969.409482
# dtype: object

# %%
all_merged.skew()
# Out:
# Transaction ID        0.000072
# Company               1.245382
# KM Travelled          0.055779
# Price Charged         0.873761
# Cost of Trip          0.137958
# Customer ID           0.880030
# Age                   0.685339
# Income (USD/Month)    0.309562
# dtype: float64

# %%
all_merged.kurt()
# Out:
# Transaction ID       -1.198925
# Company              -0.449026
# KM Travelled         -1.126875
# Price Charged         0.747635
# Cost of Trip         -1.012233
# Customer ID          -0.885062
# Age                  -0.458397
# Income (USD/Month)   -0.660486
# dtype: float64

# %%
all_merged.mode(axis=0, numeric_only=False, dropna=True)
# Out:
#         Transaction ID Date of Travel  Company         City  KM Travelled  \
# 0             10000011     2018-01-05      1.0  NEW YORK NY          33.6
# 1             10000012            NaT      NaN          NaN           NaN
# 2             10000013            NaT      NaN          NaN           NaN
# 3             10000014            NaT      NaN          NaN           NaN
# 4             10000015            NaT      NaN          NaN           NaN
# ...                ...            ...      ...          ...           ...
# 359387        10440101            NaT      NaN          NaN           NaN
# 359388        10440104            NaT      NaN          NaN           NaN
# 359389        10440105            NaT      NaN          NaN           NaN
# 359390        10440106            NaT      NaN          NaN           NaN
# 359391        10440107            NaT      NaN          NaN           NaN
#
#         Price Charged  Cost of Trip  Customer ID Gender   Age  \
# ...

# %%
all_merged.nunique()
# Out:
# Transaction ID        359392
# Date of Travel          1095
# Company                    2
# City                      19
# KM Travelled             874
# Price Charged          99176
# Cost of Trip           16291
# Customer ID            46148
# Gender                     2
# Age                       48
# Income (USD/Month)     22725
# Payment_Mode               2
# Day                        7
# dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.histplot(data = all_merged['Payment_Mode'], bins = 25)
# Out:
# <AxesSubplot: xlabel='Payment_Mode', ylabel='Count'>

# %%
sns.displot(data = all_merged, x="Income (USD/Month)", hue="Payment_Mode", bins = 20)

# %%
sns.displot(data = all_merged, x="Income (USD/Month)", hue="Payment_Mode", kind="kde", fill=True)

# %%
sns.displot(data = all_merged, x="Income (USD/Month)", hue="Gender", kind="kde", fill=True)

# %%
plt.figure(figsize=(4,3))
sns.boxplot(data = all_merged, x="Income (USD/Month)", y ="Gender")
# Out:
# <AxesSubplot: xlabel='Income (USD/Month)', ylabel='Gender'>

# %%
sns.displot(data = all_merged, x="Income (USD/Month)", hue="Company", bins = 20)

# %%
sns.displot(data = all_merged, x="Income (USD/Month)", hue="Company", kind="kde", fill=True)

# %%
sns.displot(data = all_merged, x="Income (USD/Month)", hue="Gender", kind="kde", fill=True)

# %%
sns.displot(data = all_merged, x="Income (USD/Month)", col="Payment_Mode", bins = 25)

# %%
sns.displot(data = all_merged, x="Income (USD/Month)", col="Company", bins = 25)

# %%
sns.displot(data = all_merged, x="KM Travelled", hue="Payment_Mode", bins = 20)

# %%
sns.displot(data = all_merged, x="Price Charged", hue="Payment_Mode", bins = 20)

# %%
sns.displot(data = all_merged, x="Cost of Trip", hue="Payment_Mode", bins = 20)

# %%
sns.displot(data = all_merged, x="Cost of Trip", hue="Company", bins = 20)

# %% [markdown]
# We can see here that Company 1(Yellow) cost of trip was more than the company 2(Pink).

# %%
sns.displot(data = all_merged, x="Price Charged", hue="Gender", bins = 20)

# %%
sns.displot(data = all_merged, x="Price Charged", hue="Company", bins = 20)

# %% [markdown]
# We can see here that Company 1(Yellow) charged more price than the company 2(Pink).

# %%
sns.displot(data = all_merged, x="Cost of Trip", hue="Gender", multiple="dodge", bins = 10)

# %%
sns.displot(data = all_merged, x="Cost of Trip", hue="Payment_Mode", multiple="dodge", bins = 10)

# %% [markdown]
# Card is used more than Cash for mode of Transaction in Cab Industry.

# %%
sns.displot(data = all_merged, x="Income (USD/Month)", hue="City", bins = 15)

# %% [markdown]
# As we can see NYC users has the highest amount of Income compared to other cities.

# %%
city = pd.read_csv('/Users/krutarthmac/Downloads/DataSets-main/City.csv')

# %%
city = city.sort_index(axis = 1)

# %%
city
# Out:
#                 City   Population      Users
# 0        NEW YORK NY   8,405,837    302,149
# 1         CHICAGO IL   1,955,130    164,468
# 2     LOS ANGELES CA   1,595,037    144,132
# 3           MIAMI FL   1,339,155     17,675
# 4     SILICON VALLEY   1,177,609     27,247
# 5      ORANGE COUNTY   1,030,185     12,994
# 6       SAN DIEGO CA     959,307     69,995
# 7         PHOENIX AZ     943,999      6,133
# 8          DALLAS TX     942,908     22,157
# 9         ATLANTA GA     814,885     24,701
# 10         DENVER CO     754,233     12,421
# 11         AUSTIN TX     698,371     14,978
# 12        SEATTLE WA     671,238     25,063
# 13         TUCSON AZ     631,442      5,712
# 14  SAN FRANCISCO CA     629,591    213,609
# 15     SACRAMENTO CA     545,776      7,044
# 16     PITTSBURGH PA     542,085      3,643
# 17     WASHINGTON DC     418,859    127,001
# 18      NASHVILLE TN     327,225      9,270
# 19         BOSTON MA     248,968     80,021

# %%
sns.displot(data = city, x="Users", y = 'Population', hue="City")
plt.xticks(rotation=90, fontsize=8)
plt.show()

# %%
all_merged["Profit"] = all_merged["Price Charged"] - all_merged["Cost of Trip"]

# %%
all_merged.head(5)
# Out:
#        Transaction ID Date of Travel  Company            City  KM Travelled  \
# 11294        10000832     2016-01-02        1     NEW YORK NY         29.29
# 11537        10001234     2016-01-02        1      SEATTLE WA         39.60
# 6830         10000365     2016-01-02        2  SILICON VALLEY          9.00
# 6835         10000370     2016-01-02        2       TUCSON AZ          5.40
# 6840         10000375     2016-01-02        2   WASHINGTON DC          3.03
#
#        Price Charged  Cost of Trip  Customer ID Gender  Age  \
# 11294         907.43       369.054         1022   Male   20
# 11537        1119.67       541.728        38146   Male   36
# 6830          167.18        90.000        14340   Male   42
# 6835           94.49        58.320        39975   Male   40
# 6840           33.57        30.300        51011   Male   53
#
#        Income (USD/Month) Payment_Mode       Day   Profit
# 11294               22359         Card  Saturday  538.376
# ...

# %%
yellow_cab_profit = all_merged[all_merged['Company']== 1]

# %%
pink_cab_profit = all_merged[all_merged['Company']== 2]

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(data=all_merged, x="Profit", y="Income (USD/Month)", hue = 'Company')
# Out:
# <AxesSubplot: xlabel='Profit', ylabel='Income (USD/Month)'>

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(data=all_merged, x="Profit", y="Price Charged", hue = 'Company')
# Out:
# <AxesSubplot: xlabel='Profit', ylabel='Price Charged'>

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(data=all_merged, x="Profit", y="Price Charged", hue = 'Gender')
# Out:
# <AxesSubplot: xlabel='Profit', ylabel='Price Charged'>

# %%
plt.figure(figsize=(5,3))
sns.lmplot(data=all_merged, x="Profit", y="Price Charged");

# %%
plt.figure(figsize=(5,3))
sns.lmplot(data=all_merged, x="Profit", y="Price Charged", hue = 'Company');

# %%
sns.barplot(x='Day', y = 'Profit', data=all_merged)
# Out:
# <AxesSubplot: xlabel='Day', ylabel='Profit'>

# %% [markdown]
# As expected more profits are being made on Weekends.

# %%
all_merged['Month'] = all_merged['Date of Travel'].dt.month

# %%
all_merged.Month.value_counts().plot()
# Out:
# <AxesSubplot: >

# %%
all_merged[['KM Travelled', 'Price Charged', 'Cost of Trip', 'Profit']].corr(method ='pearson')
# Out:
#                KM Travelled  Price Charged  Cost of Trip    Profit
# KM Travelled       1.000000       0.835753      0.981848  0.462768
# Price Charged      0.835753       1.000000      0.859812  0.864154
# Cost of Trip       0.981848       0.859812      1.000000  0.486056
# Profit             0.462768       0.864154      0.486056  1.000000

# %% [markdown]
# We can see that throught out the years the number of users in each month are incresing except for first month.

# %% [markdown]
# ### Hypothesis Testing

# %% [markdown]
# #### Shapiro-Wilk Test - Checks whether a data sample has a Gaussian distribution.
#
# H0: the sample has a Gaussian distribution. <br>
# H1: the sample does not have a Gaussian distribution.

# %%
from scipy.stats import shapiro

# %%
stat, p = shapiro(all_merged['Income (USD/Month)'])
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably Gaussian distribution')
else:
    print('Probably not Gaussian distribution')
# Out:
# stat=0.971, p=0.000
# Probably not Gaussian distribution

# %%
stat, p = shapiro(all_merged['Cost of Trip'])
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably Gaussian distribution')
else:
    print('Probably not Gaussian distribution')
# Out:
# stat=0.969, p=0.000
# Probably not Gaussian distribution

# %%
stat, p = shapiro(all_merged['Price Charged'])
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably Gaussian distribution')
else:
    print('Probably not Gaussian distribution')
# Out:
# stat=0.947, p=0.000
# Probably not Gaussian distribution

# %%
stat, p = shapiro(all_merged['KM Travelled'])
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably Gaussian distribution')
else:
    print('Probably not Gaussian distribution')
# Out:
# stat=0.963, p=0.000
# Probably not Gaussian distribution

# %% [markdown]
# #### ANOVA - Analysis of Variance Test : Tests whether the means of two or more independent samples are significantly different.
#
# H0: the means of the samples are equal. <br>
# H1: one or more of the means of the samples are unequal.

# %%
from scipy.stats import f_oneway

# %%
stat, p = f_oneway(all_merged['Price Charged'], all_merged['KM Travelled'],all_merged['Profit'])
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably the same distribution')
else:
    print('Probably different distributions')
# Out:
# stat=454438.858, p=0.000
# Probably different distributions

# %% [markdown]
# #### Nonparametric Statistical Hypothesis Test : Tests whether the distributions of two independent samples are equal or not.
#
# #### Kruskal-Wallis H Test
#
# H0: the distributions of both samples are equal. <br>
# H1: the distributions of both samples are not equal.

# %%
from scipy.stats import kruskal

# %%
stat, p = kruskal(yellow_cab_profit['Profit'], pink_cab_profit['Profit'])
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably the same distribution')
else:
    print('Probably different distributions')
# Out:
# stat=28414.066, p=0.000
# Probably different distributions

# %% [markdown]
# #### Mann-Whitney U Test
#
# H0: the distributions of both samples are equal. <br>
# H1: the distributions of both samples are not equal.

# %%
from scipy.stats import mannwhitneyu

# %%
stat, p = mannwhitneyu(yellow_cab_profit['Profit'], pink_cab_profit['Profit'])
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably the same distribution')
else:
    print('Probably different distributions')
# Out:
# stat=16084098181.000, p=0.000
# Probably different distributions

# %% [markdown]
# #### Parametric Statistical Hypothesis Tests :

# %% [markdown]
# #### Student’s t-test : Tests whether the means of two independent samples are significantly different.
#
# H0: the means of the samples are equal. <br>
# H1: the means of the samples are unequal.

# %%
from scipy.stats import ttest_ind

# %%
stat, p = ttest_ind(yellow_cab_profit['Profit'], pink_cab_profit['Profit'])
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably the same distribution')
else:
    print('Probably different distributions')
# Out:
# stat=160.372, p=0.000
# Probably different distributions

# %%
stat, p = ttest_ind(all_merged['Cost of Trip'], all_merged['KM Travelled'])
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably the same distribution')
else:
    print('Probably different distributions')
# Out:
# stat=997.309, p=0.000
# Probably different distributions

# %%
stat, p = ttest_ind(all_merged['Cost of Trip'], all_merged['Price Charged'])
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably the same distribution')
else:
    print('Probably different distributions')
# Out:
# stat=-259.880, p=0.000
# Probably different distributions

# %%
stat, p = ttest_ind(all_merged['Profit'], all_merged['KM Travelled'])
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably the same distribution')
else:
    print('Probably different distributions')
# Out:
# stat=427.630, p=0.000
# Probably different distributions
